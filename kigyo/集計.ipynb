# %%
import pandas as pd

# %%
ls
# Out:
# 1500_1900.ipynb        jinzai_final.ipynb     kigyo1900_2200.csv
# 1900_2200.ipynb        kanagawa.ipynb         kigyo2200_last.csv
# 2200_last.ipynb        kanagawa.xlsx          kigyo_1000.csv
# jinzai.ipynb           kigyo1000_1500.csv     集計.ipynb
# jinzai1000-1500.ipynb  kigyo1500_1900.csv

# %%
df1 = pd.read_csv("kigyo_1000.csv")
df2 = pd.read_csv("kigyo1000_1500.csv")
df3 = pd.read_csv("kigyo1500_1900.csv")
df4 = pd.read_csv("kigyo1900_2200.csv")
df5 = pd.read_csv("kigyo2200_last.csv")

# %%
concat = pd.concat([df1,df2,df3,df4,df5]).iloc[:,1:]

# %%
concon=concat.drop_duplicates()

# %%
concon
# Out:
#      許可・受理番号\n／許可年月日・\n届出受理年月日                         事業主名称/\n事業所名称  \
# 0      派01-010028\n昭和63年09月01日    株式会社ツーリストサービス北海道\n株式会社ツーリストサービス北海道
# 1      派01-010033\n平成01年10月01日  株式会社ケイ・イー・パワースタッフ\n株式会社ケイ・イー・パワースタッフ
# 2      派01-010050\n平成03年06月01日              キャリアバンク株式会社\nキャリアバンク株式会社
# 3      派01-010050\n平成03年06月01日         キャリアバンク株式会社\nキャリアバンク株式会社　函館支店
# 4      派01-010050\n平成03年06月01日         キャリアバンク株式会社\nキャリアバンク株式会社　旭川支店
# ...                        ...                                   ...
# 1581   派47-300348\n令和02年08月01日              株式会社パニパニワーク\n株式会社パニパニワーク
# 1582   派47-300349\n令和02年09月01日                    株式会社七和\n株式会社七和事業本部
# 1583   派47-300351\n令和02年08月01日            有限会社ジョイントクルー\n有限会社ジョイントクルー
# 1584   派47-300352\n令和02年09月01日                株式会社ジョブコラボ\n株式会社ジョブコラボ
# 1585   派47-300353\n令和02年12月01日        一般社団法人沖縄しまたて協会\n一般社団法人沖縄しまたて協会
#
#                               会社url  \
# 0                               NaN
# 1                               NaN
# ...

# %%
concon.to_excel("kigyo_fin.xlsx")
